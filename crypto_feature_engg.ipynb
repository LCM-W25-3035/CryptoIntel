# %%
 #Feature Engineering

#adding coloumns
#Calculate the price spread for each pair:

df['Spread'] = df['High'] - df['Low']
Price Position in Range:

#Calculate the position of the Last Price within the range:

df['Position'] = (df['Last Price'] - df['Low']) / (df['High'] - df['Low'])
Percentage Volatility:

#Compute the percentage volatility of each cryptocurrency:

df['Volatility'] = ((df['High'] - df['Low']) / df['Low']) * 100
Time-Based Features:

#Extract features like hour and minute from the Timestamp column:

df['Hour'] = df['Timestamp'].dt.hour
df['Minute'] = df['Timestamp'].dt.minute
Rolling Averages (if required):

#Compute rolling averages for prices or volume over a time window:

df['Rolling_Avg_Volume'] = df['Volume'].rolling(window=3).mean()

# %% [markdown]
# What the dataset will look like:

# %% [markdown]
# ![Screenshot 2025-02-03 012122.png](data:image/png;base64,...)
